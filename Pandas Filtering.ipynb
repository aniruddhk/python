# %% [markdown]
# # Pandasc - Filtering

# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv')

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# ...

# %%
filter1 = (df['RemoteWork']=='Fully remote') & (df['MainBranch']=='I am a developer by profession')

# %%
df[filter1]
# Out:
#        ResponseId                      MainBranch  \
# 1               2  I am a developer by profession
# 3               4  I am a developer by profession
# 9              10  I am a developer by profession
# 13             14  I am a developer by profession
# 14             15  I am a developer by profession
# ...           ...                             ...
# 73240       73241  I am a developer by profession
# 73246       73247  I am a developer by profession
# 73248       73249  I am a developer by profession
# 73250       73251  I am a developer by profession
# 73263       73264  I am a developer by profession
#
#                                               Employment    RemoteWork  \
# 1                                    Employed, full-time  Fully remote
# 3                                    Employed, full-time  Fully remote
# 9      Independent contractor, freelancer, or self-em...  Fully remote
# 13                                   Employed, part-time  Fully remote
# ...

# %%
df.loc[~filter1, ['EdLevel']]
# Out:
#                                                  EdLevel
# 0                                                    NaN
# 2        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 6      Secondary school (e.g. American high school, G...
# ...                                                  ...
# 73262  Secondary school (e.g. American high school, G...
# 73264    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73265       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73266       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73267       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
# [50593 rows x 1 columns]

# %%
filter2 = df['ConvertedCompYearly']>100000
temp_df = df[filter2]
temp_df
# Out:
#        ResponseId                                         MainBranch  \
# 3               4                     I am a developer by profession
# 11             12  I am not primarily a developer, but I write co...
# 14             15                     I am a developer by profession
# 17             18                     I am a developer by profession
# 26             27                     I am a developer by profession
# ...           ...                                                ...
# 73101       73102                     I am a developer by profession
# 73102       73103                     I am a developer by profession
# 73105       73106                     I am a developer by profession
# 73111       73112                     I am a developer by profession
# 73116       73117                     I am a developer by profession
#
#                                               Employment  \
# 3                                    Employed, full-time
# ...

# %%
#countries = ['India', 'United Kingdom','United States']
#countries_df  = temp_df['country'].isin(countries)

# %%
filter3 = df['EdLevel'].str.contains('M.S.', na=False)

# %%
filter3
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 73263    False
# 73264     True
# 73265    False
# 73266    False
# 73267    False
# Name: EdLevel, Length: 73268, dtype: bool

# %%
temp_df.loc[filter3,'EdLevel']
# Out:
# 14       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 17       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 28       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 29       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 55       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#                               ...
# 72950    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 72954    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 72971    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 72975    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73026    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Name: EdLevel, Length: 3136, dtype: object
